# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
five_df = pd.read_csv('Five_year.csv')

# %%
#head

five_df.head()
# Out:
#    Survival Rate  Year       Race   Gender  Cancer Type
# 0          0.559  1977  All races  females  All cancers
# 1          0.550  1980  All races  females  All cancers
# 2          0.551  1983  All races  females  All cancers
# 3          0.576  1986  All races  females  All cancers
# 4          0.596  1989  All races  females  All cancers

# %%
#info

five_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1887 entries, 0 to 1886
# Data columns (total 5 columns):
# Survival Rate    1666 non-null float64
# Year             1887 non-null int64
# Race             1887 non-null object
# Gender           1887 non-null object
# Cancer Type      1887 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 73.8+ KB

# %%
#describe

five_df.describe()
# Out:
#        Survival Rate         Year
# count    1666.000000  1887.000000
# mean        0.436878  1990.054054
# std         0.296259    12.777824
# min         0.000000  1963.000000
# 25%         0.162000  1980.000000
# 50%         0.391000  1989.000000
# 75%         0.680000  1998.000000
# max         1.000000  2013.000000

# %%
#data vizualization

five_df.keys()
# Out:
# Index(['Survival Rate', 'Year', 'Race', 'Gender', 'Cancer Type'], dtype='object')

# %%
five_df['Cancer Type']
# Out:
# 0       All cancers
# 1       All cancers
# 2       All cancers
# 3       All cancers
# 4       All cancers
# 5       All cancers
# 6       All cancers
# 7       All cancers
# 8       All cancers
# 9       All cancers
# 10      All cancers
# 11      All cancers
# 12      All cancers
# 13      All cancers
# 14      All cancers
# 15      All cancers
# 16      All cancers
# 17      All cancers
# 18      All cancers
# 19      All cancers
# 20      All cancers
# 21      All cancers
# 22      All cancers
# 23      All cancers
# 24      All cancers
# 25      All cancers
# 26      All cancers
# 27      All cancers
# 28      All cancers
# 29      All cancers
#            ...
# 1857        Thyroid
# 1858        Thyroid
# 1859        Thyroid
# 1860        Thyroid
# 1861        Thyroid
# 1862        Thyroid
# 1863        Thyroid
# 1864        Thyroid
# 1865        Thyroid
# 1866        Thyroid
# 1867        Thyroid
# 1868        Thyroid
# 1869        Thyroid
# 1870        Thyroid
# ...

# %%
sns.countplot(five_df['Year'],label ='count')

# %%
five_df.corr()
# Out:
#                Survival Rate      Year
# Survival Rate       1.000000  0.203635
# Year                0.203635  1.000000

# %%
sns.jointplot(x='Survival Rate',y='Year',data=five_df)
# Out:
# C:\Users\francis\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\francis\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Survival Rate',y='Year',kind='kde',color='red',data=five_df)

# %%
five_df.head(50)
# Out:
#    Survival Rate  Year       Race   Gender  Cancer Type
# 0          0.559  1977  All races  females  All cancers
# 1           0.55  1980  All races  females  All cancers
# 2          0.551  1983  All races  females  All cancers
# 3          0.576  1986  All races  females  All cancers
# 4          0.596  1989  All races  females  All cancers
# 5          0.609  1992  All races  females  All cancers
# 6          0.618  1995  All races  females  All cancers
# 7          0.636  1998  All races  females  All cancers
# 8          0.657  2001  All races  females  All cancers
# 9          0.669  2006  All races  females  All cancers
# 10         0.691  2013  All races  females  All cancers
# 11         0.417  1977  All races  females  All cancers
# 12         0.431  1980  All races  females  All cancers
# 13         0.452  1983  All races  females  All cancers
# 14         0.472  1986  All races  females  All cancers
# 15         0.511  1989  All races  females  All cancers
# ...

# %%
five_df['Gender']
# Out:
# 0       females
# 1       females
# 2       females
# 3       females
# 4       females
# 5       females
# 6       females
# 7       females
# 8       females
# 9       females
# 10      females
# 11        males
# 12        males
# 13        males
# 14        males
# 15        males
# 16        males
# 17        males
# 18        males
# 19        males
# 20        males
# 21        males
# 22        total
# 23        total
# 24        total
# 25        total
# 26        total
# 27        total
# 28        total
# 29        total
#          ...
# 1857    females
# 1858    females
# 1859    females
# 1860    females
# 1861      males
# 1862      males
# 1863      males
# 1864      males
# 1865      males
# 1866      males
# 1867      males
# 1868      males
# 1869      males
# 1870      males
# 1871      males
# 1872      males
# 1873      males
# 1874      total
# 1875      total
# 1876      total
# 1877      total
# 1878      total
# 1879      total
# 1880      total
# ...

# %%
survivalrate_50 = five_df[(five_df['Year']) & (five_df['Survival Rate'] > 0.5)]

# %%
# Out:
#                Survival Rate      Year
# Survival Rate       1.000000  0.153206
# Year                0.153206  1.000000

# %%
sns.jointplot(x='Survival Rate',y='Year',kind='kde',color='red',data=survivalrate_50)

# %%
five_df.isna().sum()
# Out:
# Survival Rate    221
# Year               0
# Race               0
# Gender             0
# Cancer Type        0
# dtype: int64

# %%
five_df['Survival Rate'].median()
# Out:
# 0.391

# %%
five_df['Survival Rate']= five_df.fillna(five_df['Survival Rate'].median())

# %%
five_df.isna().sum()
# Out:
# Survival Rate    0
# Year             0
# Race             0
# Gender           0
# Cancer Type      0
# dtype: int64

# %%
five_df.head(50)
# Out:
#    Survival Rate  Year       Race Gender  Cancer Type
# 0          0.559  1977  All races  males  All cancers
# 1           0.55  1980  All races  males  All cancers
# 2          0.551  1983  All races  males  All cancers
# 3          0.576  1986  All races  males  All cancers
# 4          0.596  1989  All races  males  All cancers
# 5          0.609  1992  All races  males  All cancers
# 6          0.618  1995  All races  males  All cancers
# 7          0.636  1998  All races  males  All cancers
# 8          0.657  2001  All races  males  All cancers
# 9          0.669  2006  All races  males  All cancers
# 10         0.691  2013  All races  males  All cancers
# 11         0.417  1977  All races  males  All cancers
# 12         0.431  1980  All races  males  All cancers
# 13         0.452  1983  All races  males  All cancers
# 14         0.472  1986  All races  males  All cancers
# 15         0.511  1989  All races  males  All cancers
# ...

# %%
survivalrate_50 = five_df[(five_df['Year']) & (five_df['Survival Rate'] > 0.5)]

# %%
sns.jointplot(x='Survival Rate',y='Year',kind='kde',color='red',data=survivalrate_50)

# %%
def find_outliers_tukey(x):
    q1 = x.quantile(.25)
    q3 = x.quantile(.75)
    iqr = q3 - q1
    floor = q1 - 1.5*iqr
    ceiling = q3 + 1.5*iqr
    outlier_indices = list(x.index[(x < floor) | (x > ceiling)])
    outlier_values = list(x[outlier_indices])
    return outlier_indices, outlier_values

# %%
five_df['Gender'].value_counts()
# Out:
# males      629
# total      629
# females    629
# Name: Gender, dtype: int64

# %%
sns.jointplot(x='Survival Rate',y='Year',kind='kde',color='red',data=five_df)

# %%
m = {'m' : 1, 'f' : 0}

# %%
five_df['Gender'] = five_df['Gender'].str[0].str.lower().map(m)

# %%
five_df['Gender'].value_counts()
# Out:
# 1.0    629
# 0.0    629
# Name: Gender, dtype: int64

# %%
sns.kdeplot(five_df['Survival Rate'])
# Out:
# C:\Users\francis\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\francis\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
five_df.corr()
# Out:
#                Survival Rate      Year    Gender
# Survival Rate       1.000000  0.203635 -0.046534
# Year                0.203635  1.000000  0.000000
# Gender             -0.046534  0.000000  1.000000

# %%
sns.heatmap(five_df.corr(),annot= True)

# %%
five_df
# Out:
#      Survival Rate  Year       Race   Gender  Cancer Type
# 0            0.559  1977  All races  females  All cancers
# 1             0.55  1980  All races  females  All cancers
# 2            0.551  1983  All races  females  All cancers
# 3            0.576  1986  All races  females  All cancers
# 4            0.596  1989  All races  females  All cancers
# 5            0.609  1992  All races  females  All cancers
# 6            0.618  1995  All races  females  All cancers
# 7            0.636  1998  All races  females  All cancers
# 8            0.657  2001  All races  females  All cancers
# 9            0.669  2006  All races  females  All cancers
# 10           0.691  2013  All races  females  All cancers
# 11           0.417  1977  All races    males  All cancers
# 12           0.431  1980  All races    males  All cancers
# 13           0.452  1983  All races    males  All cancers
# 14           0.472  1986  All races    males  All cancers
# ...

# %%
gender = five_df.pivot_table(index='Race',columns='Year',values='Survival Rate',aggfunc='first')

# %%
plt.figure(figsize=(10,5))
sns.heatmap(gender,annot = True)

# %%
Cancer = five_df.pivot_table(index='Cancer Type',columns='Year',values='Survival Rate',aggfunc='first')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(Cancer,annot = True)

# %%
Cancer
# Out:
# Year                       1963   1973   1977   1980   1983   1986   1989  \
# Cancer Type
# All cancers               0.391  0.391  0.559  0.550  0.551  0.576  0.596
# Bladder                   0.240  0.270  0.683  0.704  0.727  0.727  0.719
# Brain and nervous system  0.210  0.190  0.248  0.251  0.255  0.285  0.310
# Breast                    0.460  0.510  0.748  0.744  0.761  0.789  0.840
# Cervix uteri              0.470  0.610  0.691  0.674  0.669  0.672  0.701
# Colon and rectum          0.391  0.391  0.506  0.522  0.542  0.576  0.593
# Esophagus                 0.020  0.030  0.075  0.056  0.082  0.121  0.095
# Leukemia                  0.391  0.391  0.356  0.373  0.378  0.411  0.413
# Liver                     0.391  0.391  0.063  0.054  0.052  0.095  0.080
# Lung and bronchus         0.060  0.100  0.153  0.163  0.164  0.160  0.150
# Myeloma                   0.391  0.391  0.253  0.275  0.294  0.269  0.255
# ...
